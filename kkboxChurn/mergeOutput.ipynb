# %%
import numpy as np
import pandas as pd

# %%
rnn_result = np.load('result/predicted_test.npy')
rnn_result.shape
# Out:
# 0.0

# %%
resultDf = pd.read_csv('active_user_label_test.csv').loc[:,['msno','is_churn']]
resultDf.shape
# Out:
# (788360, 2)

# %%
lrResultDf = pd.read_csv('result/lr_result.csv')
lrResultDf.head()
# Out:
#                                            msno  is_churn
# 0  4n+fXlyJvfQnTeKXTWT507Ll4JVYGrOC8LHCfwBmPE4=         0
# 1  aNmbC1GvFUxQyQUidCVmfbQ0YeCuwkPzEdQ0RwWyeZM=         0
# 2  rFC9eSG/tMuzpre6cwcMLZHEYM89xY02qcz7HL4//jc=         0
# 3  WZ59dLyrQcE7ft06MZ5dj40BnlYQY7PHgg/54+HaCSE=         0
# 4  aky/Iv8hMp1/V/yQHLtaVuEmmAxkB5GuasQZePJ7NU4=         0

# %%
pd.read_csv('data/sample_submission_v2.csv')
# Out:
#                                                 msno  is_churn
# 0       4n+fXlyJvfQnTeKXTWT507Ll4JVYGrOC8LHCfwBmPE4=         0
# 1       aNmbC1GvFUxQyQUidCVmfbQ0YeCuwkPzEdQ0RwWyeZM=         0
# 2       rFC9eSG/tMuzpre6cwcMLZHEYM89xY02qcz7HL4//jc=         0
# 3       WZ59dLyrQcE7ft06MZ5dj40BnlYQY7PHgg/54+HaCSE=         0
# 4       aky/Iv8hMp1/V/yQHLtaVuEmmAxkB5GuasQZePJ7NU4=         0
# 5       nu1jZ/flvSaXRg0U9Es+xmo2KlAXq/q+mhcWFStwm9w=         0
# 6       biDTtgK83fEWXJDaxzD1eh22dion/h3odeIbS7qJMmY=         0
# 7       k/8uwi/iM9LZmRAIWXLqpZY6ENomXAscwsQsh6PxcTw=         0
# 8       18rQ/746SjA6nBx325UsyhfsDhu4tK01FXFxHWZjw20=         0
# 9       2V13OCoWx6vqKr/ZzNmKFrmnC2FtR4SWMz5C5Hi02PY=         0
# 10      1l/ZwduFxS/q/hZeyssAYH27espkp8Yw6uAnUxfEbTI=         0
# 11      azfnO16ZeQsbJF6LcqkQhbA3NWiqHYWqaq7AFjsJVaQ=         0
# 12      RPOzeEr8mSbhj6wrF29+7KciuiNrj7IvkzxJ9rgCTks=         0
# 13      NAzfjSM2EOyFhV4rIm/RO9pXCbyti6scBfcmV/t+CaU=         0
# ...

# %%
resultDf= resultDf.iloc[:788320]
resultDf.is_churn = rnn_result
resultDf.head()
# Out:
#                                            msno  is_churn
# 0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=       0.0
# 1  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=       0.0
# 2  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=       0.0
# 3  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=       0.0
# 4  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=       0.0

# %%
lrResultDf.is_churn.unique()
# Out:
# array([0, 1])
